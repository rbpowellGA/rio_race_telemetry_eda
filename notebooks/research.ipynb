# %%
import pandas as  pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('../data/race_data/telemetry-rio-5-laps.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0  since_last_ns  timestamp_ms  current_engine_rpm  \
# 0           0              0      27901812           4985.9053
# 1           1        7438900      27901828           4985.5083
# 2           2        8171000      27901828           4964.7420
# 3           3        8336100      27901843           4949.4760
# 4           4        8430500      27901843           4939.9850
# 5           5        8331900      27901859           4936.4746
# 6           6        8255500      27901859           4938.8360
# 7           7        8312400      27901875           4946.8100
# 8           8        8209400      27901875           4959.9650
# 9           9        8372500      27901890           4977.7065
#
#    wheel_rotation_speed_front_left  wheel_rotation_speed_front_right  \
# 0                        66.646460                         66.550380
# 1                        66.634400                         66.541245
# ...

# %%
df.corr()
# Out:
#                                  Unnamed: 0  since_last_ns  timestamp_ms  \
# Unnamed: 0                         1.000000       0.000579      1.000000
# since_last_ns                      0.000579       1.000000      0.000580
# timestamp_ms                       1.000000       0.000580      1.000000
# current_engine_rpm                 0.054010       0.001369      0.054012
# wheel_rotation_speed_front_left    0.027143       0.001157      0.027143
# ...                                     ...            ...           ...
# best_lap_time                      0.677749      -0.000035      0.677748
# last_lap_time                      0.690606      -0.000034      0.690604
# current_lap_time                   0.181284       0.001517      0.181287
# current_race_time                  1.000000       0.000579      1.000000
# race_position                           NaN            NaN           NaN
#
#                                  current_engine_rpm  \
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >
